# %% [markdown]
# # **Install requirements**

# %%
# !pip install gliner
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gliner
#   Using cached gliner-0.2.26-py3-none-any.whl.metadata (10 kB)
# Collecting torch>=2.0.0 (from gliner)
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting transformers<5.2.0,>=4.51.3 (from gliner)
#   Using cached transformers-5.1.0-py3-none-any.whl.metadata (31 kB)
# Collecting huggingface_hub>=0.21.4 (from gliner)
#   Using cached huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: tqdm in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gliner) (4.67.3)
# Collecting onnxruntime (from gliner)
#   Using cached onnxruntime-1.24.4-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: sentencepiece in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from gliner) (0.2.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.2.0,>=4.51.3->gliner) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.2.0,>=4.51.3->gliner) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.2.0,>=4.51.3->gliner) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.2.0,>=4.51.3->gliner) (2026.3.32)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.2.0,>=4.51.3->gliner)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer-slim (from transformers<5.2.0,>=4.51.3->gliner)
#   Using cached typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from transformers<5.2.0,>=4.51.3->gliner) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (0.28.1)
# Requirement already satisfied: typer in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from huggingface_hub>=0.21.4->gliner) (4.15.0)
# Requirement already satisfied: anyio in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.4->gliner) (4.13.0)
# Requirement already satisfied: certifi in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.4->gliner) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.4->gliner) (1.0.9)
# Requirement already satisfied: idna in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.4->gliner) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.4->gliner) (0.16.0)
# Requirement already satisfied: setuptools<82 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.0.0->gliner) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.0.0->gliner) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.0.0->gliner) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from torch>=2.0.0->gliner) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from sympy>=1.13.3->torch>=2.0.0->gliner) (1.3.0)
# Requirement already satisfied: colorama in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm->gliner) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2->torch>=2.0.0->gliner) (3.0.3)
# Requirement already satisfied: flatbuffers in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from onnxruntime->gliner) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from onnxruntime->gliner) (7.34.1)
# Requirement already satisfied: click>=8.2.1 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer->huggingface_hub>=0.21.4->gliner) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer->huggingface_hub>=0.21.4->gliner) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer->huggingface_hub>=0.21.4->gliner) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from typer->huggingface_hub>=0.21.4->gliner) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.4->gliner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from rich>=12.3.0->typer->huggingface_hub>=0.21.4->gliner) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mantheos\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.21.4->gliner) (0.1.2)
# Using cached gliner-0.2.26-py3-none-any.whl (170 kB)
# Using cached transformers-5.1.0-py3-none-any.whl (10.3 MB)
# Using cached huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached onnxruntime-1.24.4-cp313-cp313-win_amd64.whl (12.6 MB)
# Using cached typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Installing collected packages: torch, onnxruntime, typer-slim, huggingface_hub, tokenizers, transformers, gliner
#
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
#    ---------------------------------------- 0/7 [torch]
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\Mantheos\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python313\\site-packages\\torch\\include\\ATen\\native\\transformers\\cuda\\mem_eff_attention\\iterators\\predicated_tile_access_iterator_residual_last.h'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths
#
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\Mantheos\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from gliner import GLiNER
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from gliner import GLiNER
#
# ModuleNotFoundError: No module named 'gliner'

# %%
# available models: https://huggingface.co/urchade

model = GLiNER.from_pretrained("urchade/gliner_mediumv2.1")
model.eval()
print("ok")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/834M [00:00<?, ?B/s]
# gliner_config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:550: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# ok

# %%
# load text
with open("/content/529913494_Enrollee Files_ Giza_ Ladislaus THRU Gladden_ Furman.txt") as file:
  text = file.readLines()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3686/1130575891.py in <cell line: 0>()
#       1 # load text
#       2 with open("/content/529913494_Enrollee Files_ Giza_ Ladislaus THRU Gladden_ Furman.txt") as file:
# ----> 3   text = file.readLines()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'readLines'

# %%
labels = ["person", "book", "location", "date", "actor", "character"]

entities = model.predict_entities(text, labels, threshold=0.4)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Marius Petipa => person
# Trilby => character
# Charles Nodier => person
# Moscow => location
# January 25/February 6 => date
# 1870 => date
# Moscow => location
# Polina Karpakova => actor
# Trilby => character
# Ludiia Geiten => actor
# Miranda => character
# January 17–29, 1871 => date
# St. Petersburg => location
# Adèle Grantzow => actor
# Trilby => character
# Lev Ivanov => actor
# Count Leopold => character
